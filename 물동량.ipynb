# %%
import os
os.chdir("/Users/mun-yeongmin/Downloads")

# %%
import pandas as pd
volume=pd.read_csv("경상남도_연도별 물동량 및 입출항 실적_20251231.csv", encoding="cp949")
volume.head()
# Out:
#      연도  통영_선박  통영_화물  삼천포_선박  삼천포_화물  고현_선박  고현_화물  옥포_선박  옥포_화물  장승포_선박  \
# 0  2011   4482    501    2724   12187   6173   5208   6315   8550      84
# 1  2012   2813    330    2544   12181   7136  10114   5808   7077      62
# 2  2013   2462    152    2889   12297   7203   9372   6271   7864      36
# 3  2014   2569    266    2788   11753   6281   6883   6527   9203      72
# 4  2015   2749    346    3020   11723   5960   7424   5832  10003      47
#
#    장승포_화물  하동_선박  하동_화물
# 0      13    767  13911
# 1       5    614  13551
# 2       4    708  13559
# 3       3    739  12670
# 4       4    818  13255
